# %%
cd[['name', 'type', 'race', 'attribute', 'archetype']].head(10)
# Out:
#                                     name            type        race  \
# id
# 34541863        "A" Cell Breeding Device      Spell Card  Continuous
# 64163367              "A" Cell Incubator      Spell Card  Continuous
# 91231901   "A" Cell Recombination Device      Spell Card  Quick-Play
# 73262676          "A" Cell Scatter Burst      Spell Card  Quick-Play
# 98319530      "Infernoble Arms - Almace"      Spell Card       Equip
# 37478723    "Infernoble Arms - Durendal"      Spell Card       Equip
# 64867422  "Infernoble Arms - Hauteclere"      Spell Card       Equip
# 90861137     "Infernoble Arms - Joyeuse"      Spell Card       Equip
# 44256816               1st Movement Solo      Spell Card      Normal
# 86988864                  3-Hump Lacooda  Effect Monster       Beast
#
#          attribute        archetype
# id
# 34541863       NaN            Alien
# 64163367       NaN            Alien
# 91231901       NaN            Alien
# 73262676       NaN            Alien
# ...

# %%
cd[cd['race'] == 'Dragon'].head(10)
# Out:
#                                              name                     type  \
# id
# 67748760                        Absorouter Dragon           Effect Monster
# 30983281            Accel Synchro Stardust Dragon          Synchro Monster
# 56804361            Aether, the Empowering Dragon           Effect Monster
# 28865322       Aether, the Evil Empowering Dragon  Pendulum Effect Monster
# 63378869  Aiza the Dragoness of Deranged Devotion           Effect Monster
# 3410461             Alba-Lenatus the Abyss Dragon           Fusion Monster
# 37683547                          Albaz the Ashen           Effect Monster
# 87746184                Albion the Branded Dragon           Fusion Monster
# 38811586             Albion the Sanctifire Dragon           Fusion Monster
# 25451383               Albion the Shrouded Dragon           Effect Monster
#
#                                                        desc     atk     def  \
# id
# ...

# %%
cd[cd['type'] == 'Effect Monster'].head(10)
# Out:
#                                 name            type  \
# id
# 86988864              3-Hump Lacooda  Effect Monster
# 14261867            8-Claws Scorpion  Effect Monster
# 51351302            A Man with Wdjat  Effect Monster
# 13026402  A-Team: Trap Disposal Unit  Effect Monster
# 96146814                 A/D Changer  Effect Monster
# 12694768                       Abaki  Effect Monster
# 89718302               Abare Ushioni  Effect Monster
# 1966438    Abominable Unchained Soul  Effect Monster
# 70832512           Absolute Crusader  Effect Monster
# 60990740     Absolute King Back Jack  Effect Monster
#
#                                                        desc     atk     def  \
# id
# 86988864  If there are 3 face-up "3-Hump Lacooda" cards ...   500.0  1500.0
# 14261867  Once per turn, you can flip this card into fac...   300.0   200.0
# 51351302  When you Normal Summon this card, and during e...  1600.0  1600.0
# ...

# %%
cd[cd['def'] == 0].head(10)
# Out:
#                                              name            type  \
# id
# 60990740                  Absolute King Back Jack  Effect Monster
# 13014905                           Agnimal Candle   Tuner Monster
# 86377375                Ahrima, the Wicked Warden  Effect Monster
# 96084564                                  Aileron  Effect Monster
# 63378869  Aiza the Dragoness of Deranged Devotion  Effect Monster
# 37683547                          Albaz the Ashen  Effect Monster
# 47728740  Alich, Malebranche of the Burning Abyss  Effect Monster
# 85876417            Ally of Justice Thousand Arms  Effect Monster
# 27132400                       Altergeist Malwisp   Tuner Monster
# 62962630              Aluber the Jester of Despia  Effect Monster
#
#                                                        desc     atk  def  \
# id
# 60990740  During your opponent's turn (Quick Effect): Yo...     0.0  0.0
# 13014905  If this card is added to your hand, except by ...  1700.0  0.0
# ...

# %%
cd[cd['atk'] > 2000].head(5)
# Out:
#                                         name                     type  \
# id
# 65172015         A-to-Z-Dragon Buster Cannon           Fusion Monster
# 1561110                    ABC-Dragon Buster           Fusion Monster
# 1966438            Abominable Unchained Soul           Effect Monster
# 52240819             Abyss Actor - Evil Heel  Pendulum Effect Monster
# 25629622             Abyss Actor - Superstar  Pendulum Effect Monster
# 30983281       Accel Synchro Stardust Dragon          Synchro Monster
# 86066372                   Accesscode Talker             Link Monster
# 10796448              Ace★Spades Speculation           Fusion Monster
# 9464441        Adamancipator Risen - Dragite          Synchro Monster
# 47674738       Adamancipator Risen - Leonite          Synchro Monster
# 73079836       Adamancipator Risen - Raptite          Synchro Monster
# 94119480        Adreus, Keeper of Armageddon              XYZ Monster
# ...

# %%
import pandas as pd
import numpy as np

cd = pd.read_csv('YuGiOh_cards/cards.csv', index_col=0)
