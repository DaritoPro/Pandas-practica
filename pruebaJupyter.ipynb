# %%
df.iloc[500:511, 1:3]
# Out:
#                             name                  developer
# 500           Crazy Machines 1.5              Fakt Software
# 501           Crazy Machines 1.5              Fakt Software
# 502           Crazy Machines 1.5              Fakt Software
# 503                   Helldorado                 Spellbound
# 504                    Mata Hari              4Head Studios
# 505  Defense Grid: The Awakening  Hidden Path Entertainment
# 506         Mayhem Intergalactic            Inventive Dingo
# 507             And Yet It Moves               Broken Rules
# 508                    Zero Gear               Brian Cronin
# 509       Silent Hill Homecoming         Double Helix Games
# 510            Puzzle Chronicles       Infinite Interactive

# %%
df.loc[100:110, ['name', 'developer']]
# Out:
#                         name           developer
# 100       Bejeweled 2 Deluxe  PopCap Games, Inc.
# 101           Chuzzle Deluxe  PopCap Games, Inc.
# 102     Insaniquarium Deluxe  PopCap Games, Inc.
# 103              Zuma Deluxe  PopCap Games, Inc.
# 104          AstroPop Deluxe  PopCap Games, Inc.
# 105         Bejeweled Deluxe  PopCap Games, Inc.
# 106          Dynomite Deluxe  PopCap Games, Inc.
# 107          Dynomite Deluxe  PopCap Games, Inc.
# 108  Feeding Frenzy 2 Deluxe  PopCap Games, Inc.
# 109      Hammer Heads Deluxe  PopCap Games, Inc.
# 110      Heavy Weapon Deluxe  PopCap Games, Inc.

# %%
df[df['negative'] < 5000].head(10)
# Out:
#     appid                            name         developer publisher  \
# 1      20           Team Fortress Classic             Valve     Valve
# 2      30                   Day of Defeat             Valve     Valve
# 3      40              Deathmatch Classic             Valve     Valve
# 4      50       Half-Life: Opposing Force  Gearbox Software     Valve
# 5      60                        Ricochet             Valve     Valve
# 7      80  Counter-Strike: Condition Zero             Valve     Valve
# 8     100  Counter-Strike: Condition Zero             Valve     Valve
# 9     130           Half-Life: Blue Shift  Gearbox Software     Valve
# 12    280               Half-Life: Source             Valve     Valve
# 13    300           Day of Defeat: Source             Valve     Valve
#
#     score_rank  positive  negative  userscore                    owners  \
# 1          NaN      7602      1136          0    1,000,000 .. 2,000,000
# ...

# %%
df[df['positive'] > 43800].head(10)
# Out:
#     appid                              name developer publisher  score_rank  \
# 0      10                    Counter-Strike     Valve     Valve         NaN
# 6      70                         Half-Life     Valve     Valve         NaN
# 10    220                       Half-Life 2     Valve     Valve         NaN
# 11    240            Counter-Strike: Source     Valve     Valve         NaN
# 18    400                            Portal     Valve     Valve         NaN
# 20    440                   Team Fortress 2     Valve     Valve         NaN
# 21    500                       Left 4 Dead     Valve     Valve         NaN
# 22    550                     Left 4 Dead 2     Valve     Valve         NaN
# 23    620                          Portal 2     Valve     Valve         NaN
# 25    730  Counter-Strike: Global Offensive     Valve     Valve         NaN
#
#     positive  negative  userscore                      owners  \
# 0     243818      6427          0    10,000,000 .. 20,000,000
# ...

# %%
df[['name', 'developer', 'publisher']].head(20)
# Out:
#                               name         developer publisher
# 0                   Counter-Strike             Valve     Valve
# 1            Team Fortress Classic             Valve     Valve
# 2                    Day of Defeat             Valve     Valve
# 3               Deathmatch Classic             Valve     Valve
# 4        Half-Life: Opposing Force  Gearbox Software     Valve
# 5                         Ricochet             Valve     Valve
# 6                        Half-Life             Valve     Valve
# 7   Counter-Strike: Condition Zero             Valve     Valve
# 8   Counter-Strike: Condition Zero             Valve     Valve
# 9            Half-Life: Blue Shift  Gearbox Software     Valve
# 10                     Half-Life 2             Valve     Valve
# 11          Counter-Strike: Source             Valve     Valve
# 12               Half-Life: Source             Valve     Valve
# 13           Day of Defeat: Source             Valve     Valve
# ...

# %%
import pandas as pd
import numpy as np

df = pd.read_csv('archive/all_data.csv', index_col=0)

print(df.head())
# Out:
#    appid                       name         developer publisher  score_rank  \
# 0     10             Counter-Strike             Valve     Valve         NaN
# 1     20      Team Fortress Classic             Valve     Valve         NaN
# 2     30              Day of Defeat             Valve     Valve         NaN
# 3     40         Deathmatch Classic             Valve     Valve         NaN
# 4     50  Half-Life: Opposing Force  Gearbox Software     Valve         NaN
#
#    positive  negative  userscore                    owners  average_forever  \
# 0    243818      6427          0  10,000,000 .. 20,000,000            12222
# 1      7602      1136          0    1,000,000 .. 2,000,000              361
# 2      6414       688          0   5,000,000 .. 10,000,000              859
# 3      2618       545          0   5,000,000 .. 10,000,000              353
# 4     24363      1198          0    2,000,000 .. 5,000,000              528
#
# ...
